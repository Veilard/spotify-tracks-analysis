# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="whitegrid", palette="muted")

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610  ...    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660  ...   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590  ...    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596  ...   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430  ...    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature  track_genre
# 0          0.000001    0.3580    0.715   87.917               4     acoustic
# 1          0.000006    0.1010    0.267   77.489               4     acoustic
# 2          0.000000    0.1170    0.120   76.332               4     acoustic
# 3          0.000071    0.1320    0.143  181.740               3     acoustic
# 4          0.000000    0.0829    0.167  119.949               4     acoustic
#
# [5 rows x 21 columns]

# %%
sns.histplot(data=df, x='popularity', bins=50, kde=True, color='green')
plt.title('Popularity Distribution')
plt.xlabel('Popularity')
plt.ylabel('Track count')
plt.show()

# %%
sns.boxplot(data=df, x='popularity')
plt.title('Popularity Boxplot')
plt.show()

# %%
top_genres = (
    df.groupby('track_genre')
    .popularity.mean()
    .sort_values(ascending=False)
    .head(10)
    .index
)

top_genres
# Out:
# Index(['pop-film', 'k-pop', 'chill', 'sad', 'grunge', 'indian', 'anime', 'emo',
#        'sertanejo', 'pop'],
#       dtype='str', name='track_genre')

# %%
lowest_popularity_genres = (
    df.groupby('track_genre')
    .popularity.mean()
    .sort_values()
    .head(10)
    .index
)

lowest_popularity_genres
# Out:
# Index(['iranian', 'romance', 'latin', 'detroit-techno', 'chicago-house',
#        'classical', 'jazz', 'grindcore', 'kids', 'idm'],
#       dtype='str', name='track_genre')

# %%
sns.boxplot(
    data=df[df['track_genre'].isin(top_genres)],
    x='track_genre',
    y='popularity'
)

plt.xticks(rotation=45)
plt.title("Popularity of genres")
plt.show()

# %%
sns.boxplot(
    data=df[df['track_genre'].isin(lowest_popularity_genres)],
    x='track_genre',
    y='popularity'
)

plt.xticks(rotation=45)
plt.title("Popularity of genres")
plt.show()

# %%
#Zero popularity values analysis

zero_pop = df[df['popularity'] == 0]

print(zero_pop['track_genre'].value_counts().head(10))
print(zero_pop[['track_name', 'artists', 'track_genre']].sample(10))
# Out:
# track_genre
# jazz           681
# iranian        656
# romance        636
# soul           611
# latin          588
# country        587
# rock           525
# dance          490
# alternative    485
# house          403
# Name: count, dtype: int64
#                                            track_name  \
# 79089                               Wuthering Heights
# 19187                                     Knowing You
# 78185   Viva Colonia (Da simmer dabei, dat is prima!)
# 103277                                   Silent Night
# 3534                                  In For The Kill
# 102190                                        Flowers
# 67562                                         1, 2, 3
# 99687                                         Valerie
# 20981                                    Head & Heart
# 28295                                 Meditation Rock
#
#                                       artists        track_genre
# 79089                               Kate Bush              piano
# 19187                           Kenny Chesney            country
# 78185                                  Höhner              party
# 103277                        The Temptations               soul
# 3534                                  La Roux        alternative
# 102190                   Lauren Spencer Smith         songwriter
# 67562   Sofía Reyes;Jason Derulo;De La Ghetto              latin
# 99687                           Steve Winwood  singer-songwriter
# 20981                         Joel Corry;MNEK              dance
# 28295                          Augustus Pablo                dub

# %%
df_clean = df[df['popularity'] > 0]
# Out:
# <class 'pandas.DataFrame'>
# Index: 97980 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        97980 non-null  int64
#  1   track_id          97980 non-null  str
#  2   artists           97980 non-null  str
#  3   album_name        97980 non-null  str
#  4   track_name        97980 non-null  str
#  5   popularity        97980 non-null  int64
#  6   duration_ms       97980 non-null  int64
#  7   explicit          97980 non-null  bool
#  8   danceability      97980 non-null  float64
#  9   energy            97980 non-null  float64
#  10  key               97980 non-null  int64
#  11  loudness          97980 non-null  float64
#  12  mode              97980 non-null  int64
#  13  speechiness       97980 non-null  float64
#  14  acousticness      97980 non-null  float64
#  15  instrumentalness  97980 non-null  float64
#  16  liveness          97980 non-null  float64
#  17  valence           97980 non-null  float64
#  18  tempo             97980 non-null  float64
#  19  time_signature    97980 non-null  int64
#  20  track_genre       97980 non-null  str
# dtypes: bool(1), float64(9), int64(6), str(5)
# memory usage: 15.8 MB

# %%
sns.boxplot(
    data = df_clean[df_clean['track_genre'].isin(top_genres)],
    y='popularity',
    x='track_genre'
)
plt.show()

# %%
sns.regplot(data=df_clean.sample(2000), x="energy", y="popularity", scatter_kws={"alpha": 0.2, "color":"green"})
plt.title('Energy vs. Popularity')
plt.show()

# %%
#As we can see, energy of a song doesn't really correlate that much with its popularity.
